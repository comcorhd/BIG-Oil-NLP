# %% [markdown]
# # Tutorial Stanford’s CoreNLP

# %% [markdown]
# ## Psso 1: Instalar CoreNLP
#
# Primeiramente, temos que baixar o CoreNLP.
# O comando abaixo iniciará o download da versão do CoreNLP (3.9.2 3.9.2 em fevereiro de 2019).
#
# **Pode levar tempo dependendendo de sua velocidade de conexão com a internet ... tome um café ;)

# %%
# !wget https://nlp.stanford.edu/software/stanford-corenlp-full-2018-10-05.zip https://nlp.stanford.edu/software/stanford-english-corenlp-2018-10-05-models.jar

# %% [markdown]
# Quando o download estiver concluído, descompacte o arquivo com os seguintes comandos:

# %%
# !unzip stanford-corenlp-full-2018-10-05.zip

# %% [markdown]
# **No cmd, copie e cole os comandos abaixo:

# %%
mv stanford-english-corenlp-2018-10-05-models.jar stanford-corenlp-full-2018-10-05

# %% [markdown]
# Configure sua classpath e a localização do Stanford CoreNLP e entre no diretório

# %%
import os
os.environ["CLASSPATH"]="/home/elvis/BIG-Oil-NLP/SP/stanford-corenlp-full-2018-10-05"
os.environ["CORENLP_HOME"]="/home/elvis/BIG-Oil-NLP/SP/stanford-corenlp-full-2018-10-05"

# %% [markdown]
# ## Passo 2: Iniciar o servidor e instalar a API Python

# %% [markdown]
# Antes de fazer qualquer outra coisa, precisamos instalar a biblioteca. Assumimos que o Python 3.6 ou posterior já esteja instalado. Conforme explicado pelos desenvolvedores, a maneira mais simples de instalar o StanfordNLP é usando o pip:

# %%
# !pip3 install stanfordnlp

# %% [markdown]
# Abra o terminal e cole os comandos abaixo.
# O parâmetro -mx8g especifica a quantidade de memória que o CoreNLP pode usar. Nesse caso, são oito gigabytes. O parâmetro -timeout 5000 especifica o tempo limite em milissegundos.

# %%
cd stanford-corenlp-full-2018-10-05
java -mx8g -cp "*" edu.stanford.nlp.pipeline.StanfordCoreNLPServer -timeout 5000

# %% [markdown]
# Se desejar desligar o servidor, navegue até a janela do terminal usada para iniciá-lo anteriormente e pressione __Ctrl + C__.

# %% [markdown]
# ## Parser com CoreNLP

# %% [markdown]
# Em seguida, devemos baixar os idiomas com os quais queremos trabalhar.
#
# **Você só baixa idiomas uma vez
#
# **Cada idioma requer mais de 1 GB de espaço em disco
#
# **Leva tempo ... tome mais um café ;)

# %%
import stanfordnlp

#MODELS_DIR = '.'
#stanfordnlp.download('pt', MODELS_DIR)

# %%
## Exemplo Básico

# %%
# Inglês é o idioma padrão
# Invoque stanfordnlp.Pipeline ()
# Para o português:

nlp = stanfordnlp.Pipeline(lang='pt',treebank='pt_bosque',processors='tokenize,mwt,pos,lemma,depparse', models_dir=MODELS_DIR,  use_gpu=True, pos_batch_size=3000) # Construa o pipeline, especificamente o tamanho do lote do part-of-speech processor
doc = nlp("Processamento de língua natural (PLN) é uma subárea da ciência da computação, inteligência artificial e da linguística que estuda os problemas da geração e compreensão automática de línguas humanas naturais.") # Run the pipeline on input text
doc.sentences[0].print_tokens() # Look at the result

# %%
config = {
'processors': 'tokenize,pos,depparse', # Comma-separated list of processors to use
'lang': 'pt', # Language code for the language to build the Pipeline in
'pos_pretrain_path': '/path/to/stanfordnlp_resources/pt_bosque_models/pt_bosque.pretrain.pt',
'depparse_pretrain_path': '/path/to/stanfordnlp_resources/pt_bosque_models/pt_bosque.pretrain.pt',
'output_format': 'conllu'
}
nlp = stanfordnlp.Pipeline(**config) # Initialize the pipeline using a configuration dict
doc = nlp('''
Processamento de língua natural (PLN) é uma subárea da ciência da computação, inteligência artificial 
e da linguística que estuda os problemas da geração e compreensão automática de línguas humanas naturais. 
Sistemas de geração de língua natural convertem informação de bancos de dados de computadores em linguagem 
compreensível ao ser humano e sistemas de compreensão de língua natural convertem ocorrências de linguagem 
humana em representações mais formais, mais facilmente manipuláveis por programas de computador. 
Alguns desafios do PLN são compreensão de língua natural, 
fazer com que computadores extraiam sentido de linguagem humana ou natural e geração de língua natural.''') # Run the pipeline on input text
print(doc.conll_file.conll_as_string())

# %%
import stanfordnlp

config = {
        'lang': 'pt',
        'processors': 'tokenize,pos',
        'tokenize_pretokenized': True,
        'pos_pretrain_path': './portuguese-ud.tagger',
        'pos_batch_size': 1000
         }

nlp = stanfordnlp.Pipeline(**config)
pretokenized_text = [['PNL','é', 'desafiador','.'],['PNL','é', 'o', 'futuro']]
doc = nlp(pretokenized_text)
print(doc.conll_file.conll_as_string())
# Out:
# Use device: cpu
# ---
# Loading: tokenize
# With settings:
# {'model_path': '/home/juliana/stanfordnlp_resources/pt_bosque_models/pt_bosque_tokenizer.pt', 'pretokenized': True, 'lang': 'pt', 'shorthand': 'pt_bosque', 'mode': 'predict'}
# ---
# Loading: pos
# With settings:
# {'model_path': '/home/juliana/stanfordnlp_resources/pt_bosque_models/pt_bosque_tagger.pt', 'pretrain_path': './portuguese-ud.tagger', 'batch_size': 1000, 'lang': 'pt', 'shorthand': 'pt_bosque', 'mode': 'predict'}
# Pretrained file exists but cannot be loaded from ./portuguese-ud.tagger, due to the following exception:
# 	invalid load key, '\xac'.
# ----------------------------
# UnpicklingErrorTraceback (most recent call last)
# ~/nlp36/lib/python3.6/site-packages/stanfordnlp/models/common/pretrain.py in load(self)
#      38             try:
# ---> 39                 data = torch.load(self.filename, lambda storage, loc: storage)
#      40             except BaseException as e:
#
# ~/nlp36/lib/python3.6/site-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     528                 return _load(opened_zipfile, map_location, pickle_module, **pickle_load_args)
# --> 529         return _legacy_load(opened_file, map_location, pickle_module, **pickle_load_args)
#     530
#
# ~/nlp36/lib/python3.6/site-packages/torch/serialization.py in _legacy_load(f, map_location, pickle_module, **pickle_load_args)
#     691
# --> 692     magic_number = pickle_module.load(f, **pickle_load_args)
#     693     if magic_number != MAGIC_NUMBER:
#
# UnpicklingError: invalid load key, '\xac'.
#
# During handling of the above exception, another exception occurred:
#
# ExceptionTraceback (most recent call last)
# <ipython-input-2-8476f4fd6747> in <module>
#       9          }
#      10
# ---> 11 nlp = stanfordnlp.Pipeline(**config)
#      12 pretokenized_text = [['PNL','é', 'desafiador','.'],['PNL','é', 'o', 'futuro']]
#      13 doc = nlp(pretokenized_text)
#
# ~/nlp36/lib/python3.6/site-packages/stanfordnlp/pipeline/core.py in __init__(self, processors, lang, models_dir, treebank, use_gpu, **kwargs)
#     121                 self.processors[processor_name] = NAME_TO_PROCESSOR_CLASS[processor_name](config=curr_processor_config,
#     122                                                                                           pipeline=self,
# --> 123                                                                                           use_gpu=self.use_gpu)
#     124             except ProcessorRequirementsException as e:
#     125                 # if there was a requirements issue, add it to list which will be printed at end
#
# ~/nlp36/lib/python3.6/site-packages/stanfordnlp/pipeline/processor.py in __init__(self, config, pipeline, use_gpu)
#     100         self._trainer = None
#     101         self._vocab = None
# --> 102         self._set_up_model(config, use_gpu)
#     103         # run set up process
#     104         # build the final config for the processor
#
# ~/nlp36/lib/python3.6/site-packages/stanfordnlp/pipeline/pos_processor.py in _set_up_model(self, config, use_gpu)
#      22         self._pretrain = Pretrain(config['pretrain_path'])
#      23         # set up trainer
# ---> 24         self._trainer = Trainer(pretrain=self.pretrain, model_file=config['model_path'], use_cuda=use_gpu)
#      25
#      26     def process(self, doc):
#
# ~/nlp36/lib/python3.6/site-packages/stanfordnlp/models/pos/trainer.py in __init__(self, args, vocab, pretrain, model_file, use_cuda)
#      30         if model_file is not None:
#      31             # load everything from file
# ---> 32             self.load(pretrain, model_file)
#      33         else:
#      34             assert all(var is not None for var in [args, vocab, pretrain])
#
# ~/nlp36/lib/python3.6/site-packages/stanfordnlp/models/pos/trainer.py in load(self, pretrain, filename)
#     105         self.args = checkpoint['config']
#     106         self.vocab = MultiVocab.load_state_dict(checkpoint['vocab'])
# --> 107         self.model = Tagger(self.args, self.vocab, emb_matrix=pretrain.emb, share_hid=self.args['share_hid'])
#     108         self.model.load_state_dict(checkpoint['model'], strict=False)
#     109
#
# ~/nlp36/lib/python3.6/site-packages/stanfordnlp/models/common/pretrain.py in emb(self)
#      31     def emb(self):
#      32         if not hasattr(self, '_emb'):
# ---> 33             self._vocab, self._emb = self.load()
#      34         return self._emb
#      35
#
# ~/nlp36/lib/python3.6/site-packages/stanfordnlp/models/common/pretrain.py in load(self)
#      41                 print("Pretrained file exists but cannot be loaded from {}, due to the following exception:".format(self.filename))
#      42                 print("\t{}".format(e))
# ---> 43                 return self.read_and_save()
#      44             return data['vocab'], data['emb']
#      45         else:
#
# ~/nlp36/lib/python3.6/site-packages/stanfordnlp/models/common/pretrain.py in read_and_save(self)
#      49         # load from pretrained filename
#      50         if self._vec_filename is None:
# ---> 51             raise Exception("Vector file is not provided.")
#      52         print("Reading pretrained vectors from {}...".format(self._vec_filename))
#      53
#
# Exception: Vector file is not provided.

# %% [markdown]
# # Treinamento do modelo
# ## POS TAGGUER

# %% [markdown]
# Para treinar um modelo do tagger, é preciso criar um arquivo de propriedades (que indica parâmetros de treinamento).

# %%
# !java  -cp "*:stanford-corenlp-full-2018-10-05/*" edu.stanford.nlp.tagger.maxent.MaxentTagger -genprops
# Out:
# ## Sample properties file for maxent tagger. This file is used for three main
# ## operations: training, testing, and tagging. It may also be used to dump
# ## the contents of a model.
# ## To train or test a model, or to tag something, run:
# ##   java edu.stanford.nlp.tagger.maxent.MaxentTagger -prop <properties file>
# ## Arguments can be overridden on the commandline, e.g.:
# ##   java ....MaxentTagger -prop <properties file> -testFile /other/file
#
# # Model file name (created at train time; used at tag and test time)
# # (you can leave this blank and specify it on the commandline with -model)
# # model =
#
# # Path to file to be operated on (trained from, tested against, or tagged)
# # Specify -textFile <filename> to tag text in the given file, -trainFile <filename> to
# # to train a model using data in the given file, or -testFile <filename> to test your
# # model using data in the given file.  Alternatively, you may specify
# # -dump <filename> to dump the parameters stored in a model or
# # -convertToSingleFile <filename> to save an old, multi-file model (specified as -model)
# # to the new single file format.  The new model will be saved in the file filename.
# # If you choose to convert an old file, you must specify
# # the correct 'arch' parameter used to create the original model.
# # trainFile =
#
# # Path to outputFile to write tagged output to.
# # If empty, stdout is used.
# # outputFile =
#
# # Output format. One of: slashTags (default), xml, or tsv
# # outputFormat = slashTags
#
# # Output format options. Comma separated list.
# # currently "lemmatize" and "keepEmptySentences" are supported.
# # outputFormatOptions =
#
# # Tag separator character that separates word and pos tags
# # (for both training and test data) and used for
# # separating words and tags in slashTags format output.
# # tagSeparator = /
#
# # Encoding format in which files are stored.  If left blank, UTF-8 is assumed.
# # encoding = UTF-8
#
# # A couple flags for controlling the amount of output:
# # - print extra debugging information:
# # verbose = false
# # - print intermediate results:
# # verboseResults = true
# ######### parameters for tag and test operations #########
#
# # Class to use for tokenization. Default blank value means Penn Treebank
# # tokenization.  If you'd like to just assume that tokenization has been done,
# # and the input is whitespace-tokenized, use
# # edu.stanford.nlp.process.WhitespaceTokenizer or set tokenize to false.
# # tokenizerFactory =
#
# # Options to the tokenizer.  A comma separated list.
# # This depends on what the tokenizer supports.
# # For PTBTokenizer, you might try options like americanize=false
# # or asciiQuotes (for German!).
# # tokenizerOptions =
#
# # Whether to tokenize text for tag and test operations. Default is true.
# # If false, your text must already be whitespace tokenized.
# # tokenize = true
#
# # Write debugging information (words, top words, unknown words). Useful for
# # error analysis. Default is false.
# # debug = false
#
# # Prefix for debugging output (if debug == true). Default is to use the
# # filename from 'file'
# # debugPrefix =
#
# ######### parameters for training  #########
#
# # model architecture: This is one or more comma separated strings, which
# # specify which extractors to use. Some of them take one or more integer
# # or string
# # (file path) arguments in parentheses, written as m, n, and s below:
# # 'left3words', 'left5words', 'bidirectional', 'bidirectional5words',
# # 'generic', 'sighan2005', 'german', 'words(m,n)', 'wordshapes(m,n)',
# # 'biwords(m,n)', 'lowercasewords(m,n)', 'vbn(n)', distsimconjunction(s,m,n)',
# # 'naacl2003unknowns', 'naacl2003conjunctions', 'distsim(s,m,n)',
# # 'suffix(n)', 'prefix(n)', 'prefixsuffix(n)', 'capitalizationsuffix(n)',
# # 'wordshapes(m,n)', 'unicodeshapes(m,n)', 'unicodeshapeconjunction(m,n)',
# # 'lctagfeatures', 'order(k)', 'chinesedictionaryfeatures(s)'.
# # These keywords determines the features extracted.  'generic' is language independent.
# # distsim: Distributional similarity classes can be an added source of information
# # about your words. An English distsim file is included, or you can use your own.
# # arch =
#
# # 'wordFunction'.  A function applied to the text before training or tagging.
# # For example, edu.stanford.nlp.util.LowercaseFunction
# # This function turns all the words into lowercase
# # The function must implement java.util.function.Function<String, String>
# # Blank means no preprocessing function
# # wordFunction =
#
# # 'language'.  This is really the tag set which is used for the
# # list of open-class tags, and perhaps deterministic  tag
# # expansion). Currently we have 'english', 'arabic', 'german', 'chinese'
# # or 'polish' predefined. For your own language, you can specify
# # the same information via openClassTags or closedClassTags below
# # (only ONE of these three options may be specified).
# # 'english' means UPenn English treebank tags. 'german' is STTS
# # 'chinese' is CTB, and Arabic is an expanded Bies mapping from the ATB
# # 'polish' means some tags that some guy on the internet once used.
# # See the TTags class for more information.
# # lang =
#
# # a space-delimited list of open-class parts of speech
# # alternatively, you can specify language above to use a pre-defined list or specify the closed class tags (below)
# # openClassTags =
#
# # a space-delimited list of closed-class parts of speech
# # alternatively, you can specify language above to use a pre-defined list or specify the open class tags (above)
# # closedClassTags =
#
# # A boolean indicating whether you would like the trained model to set POS tags as closed
# # based on their frequency in training; default is false.  The frequency threshold can be set below.
# # This option is ignored if any of {openClassTags, closedClassTags, lang} are specified.
# # learnClosedClassTags =
#
# # Used only if learnClosedClassTags=true.  Tags that have fewer tokens than this threshold are
# # considered closed in the trained model.
# # closedClassTagThreshold =
#
# # search method for optimization. Normally use the default 'qn'. choices: 'qn' (quasi-Newton),
# # 'cg' (conjugate gradient, 'owlqn' (L1 regularization) or 'iis' (improved iterative scaling)
# # search = qn
#
# # for conjugate gradient or quasi-Newton search, sigma-squared smoothing/regularization
# # parameter. if left blank, the default is 0.5, which is usually okay
# # sigmaSquared = 0.5
#
# # for OWLQN search, regularization
# # parameter. if left blank, the default is 1.0, which is usually okay
# # regL1 = 1.0
#
# # For improved iterative scaling, the number of iterations, otherwise ignored
# # iterations = 100
#
# # rare word threshold. words that occur less than this number of
# # times are considered rare words.
# # rareWordThresh = 5
#
# # minimum feature threshold. features whose history appears less
# # than this number of times are ignored.
# # minFeatureThresh = 5
#
# # current word feature threshold. words that occur more than this
# # number of times will generate features with all of their occurring
# # tags.
# # curWordMinFeatureThresh = 2
#
# # rare word minimum feature threshold. features of rare words whose histories
# # appear less than this times will be ignored.
# # rareWordMinFeatureThresh = 10
#
# # very common word threshold. words that occur more than this number of
# # times will form an equivalence class by themselves. ignored unless
# # you are using equivalence classes.
# # veryCommonWordThresh = 250
#
# # sgml =
# # tagInside =
#
# # testFile and textFile can use multiple threads to process text.
# # nthreads = 1

# %% [markdown]
# Pronto o arquivo, é só rodar o tagger:
#
# O CoreNLP vai mostrar na tela o progresso do treinamento. Para avaliar o modelo treinado, basta trocar a linha do trainFile por testFile e dar o nome do arquivo com dados de teste.

# %%
# !java -cp "javanlp-core.jar:stanford-corenlp-full-2018-10-05/*" edu.stanford.nlp.tagger.maxent.MaxentTagger -prop portuguese-ud-postagger.props
# Out:
# [main] INFO edu.stanford.nlp.tagger.maxent.MaxentTagger - ## tagger training invoked at Mon Feb 10 15:37:36 BRT 2020 with arguments:
#                    model = portuguese-ud-postagger.sp
#                     arch = left3words,naacl2003unknowns,unicodeshapes(-1,1)
#             wordFunction =
#                trainFile = format=TSV,wordColumn=1,tagColumn=3,/home/elvis/BIG-Oil-NLP/SP/pt-ud-train_sem_metadados.conllu
#          closedClassTags =
#  closedClassTagThreshold = 40
#  curWordMinFeatureThresh = 2
#                    debug = false
#              debugPrefix =
#             tagSeparator =
#                 encoding = utf-8
#               iterations = 100
#                     lang =
#     learnClosedClassTags = false
#         minFeatureThresh = 2
#            openClassTags =
# rareWordMinFeatureThresh = 10
#           rareWordThresh = 5
#                   search = qn
#                     sgml = false
#             sigmaSquared = 0.0
#                    regL1 = 0.75
#                tagInside =
#                 tokenize = true
#         tokenizerFactory =
#         tokenizerOptions = asciiQuotes
#                  verbose = false
#           verboseResults = true
#     veryCommonWordThresh = 250
#                 xmlInput = null
#               outputFile =
#             outputFormat = conllu
#      outputFormatOptions =
#                 nthreads = 1
# [main] INFO edu.stanford.nlp.tagger.maxent.MaxentTagger - warning: no language set, no open-class tags specified, and no closed-class tags specified; assuming ALL tags are open class tags
# [main] INFO edu.stanford.nlp.tagger.maxent.TaggerExperiments - TaggerExperiments: adding word/tags
# [main] INFO edu.stanford.nlp.tagger.maxent.ReadDataTagged - Loading tagged words from /home/elvis/BIG-Oil-NLP/SP/pt-ud-train_sem_metadados.conllu
# [main] INFO edu.stanford.nlp.tagger.maxent.ReadDataTagged - Read 215951 words from /home/elvis/BIG-Oil-NLP/SP/pt-ud-train_sem_metadados.conllu [done].
# [main] INFO edu.stanford.nlp.tagger.maxent.ReadDataTagged - Read 8328 sentences, min 1 words, max 209 words.
# [main] INFO edu.stanford.nlp.tagger.maxent.TaggerExperiments - Featurizing tagged data tokens...
# [main] INFO edu.stanford.nlp.tagger.maxent.TaggerExperiments - Featurized 224279 data tokens [done].
# [main] INFO edu.stanford.nlp.tagger.maxent.TaggerExperiments - xSize [num Phi templates] = 177080; ySize [num classes] = 19
# [main] INFO edu.stanford.nlp.tagger.maxent.TaggerExperiments - Hashing histories ...
# [main] INFO edu.stanford.nlp.tagger.maxent.TaggerExperiments - Hashed 177080 histories.
# [main] INFO edu.stanford.nlp.tagger.maxent.TaggerExperiments - Hashing populated histories ...
# [main] INFO edu.stanford.nlp.tagger.maxent.TaggerExperiments - Hashed populated histories.
# [main] INFO edu.stanford.nlp.tagger.maxent.TaggerExperiments - TaggerExperiments.getFeaturesNew: initializing fnumArr.
# [main] INFO edu.stanford.nlp.tagger.maxent.TaggerExperiments -   length of sTemplates keys: 290784
# [main] INFO edu.stanford.nlp.tagger.maxent.TaggerExperiments - getFeaturesNew adding features ...
# [main] INFO edu.stanford.nlp.tagger.maxent.TaggerExperiments -   total feats: 290784, populated: 75337
# [main] INFO edu.stanford.nlp.tagger.maxent.TaggerExperiments -   Max features per x,y pair: 33
# [main] INFO edu.stanford.nlp.tagger.maxent.TaggerExperiments -   Max non-zero y values for an x: 19
# [main] INFO edu.stanford.nlp.tagger.maxent.TaggerExperiments -   Number of non-zero feature x,y pairs: 3055501
# [main] INFO edu.stanford.nlp.tagger.maxent.TaggerExperiments -   Number of zero feature x,y pairs: 309019
# [main] INFO edu.stanford.nlp.tagger.maxent.TaggerExperiments - end getFeaturesNew.
# [main] INFO edu.stanford.nlp.tagger.maxent.MaxentTagger - Samples from format=TSV,wordColumn=1,tagColumn=3,/home/elvis/BIG-Oil-NLP/SP/pt-ud-train_sem_metadados.conllu
# [main] INFO edu.stanford.nlp.tagger.maxent.MaxentTagger - Number of features: 75337
# [main] INFO edu.stanford.nlp.tagger.maxent.MaxentTagger - Tag set: [AUX, PRON, CCONJ, PROPN, SYM, ADJ, NUM, SCONJ, ADP, DET, ADV, .$$., PUNCT, PART, VERB, X, INTJ, NOUN, _]
# [main] INFO edu.stanford.nlp.tagger.maxent.LambdaSolveTagger -  pcond initialized
# [main] INFO edu.stanford.nlp.tagger.maxent.LambdaSolveTagger -  zlambda initialized
# [main] INFO edu.stanford.nlp.tagger.maxent.LambdaSolveTagger -  ftildeArr initialized
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - QNMinimizer called on double function of 75337 variables, using M = 10.
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 0: neg. log cond. likelihood = 660375.8298062099 [1 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer -                An explanation of the output:
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter           The number of iterations
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - evals          The number of function evaluations
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - SCALING        <D> Diagonal scaling was used; <I> Scaled Identity
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - LINESEARCH     [## M steplength]  Minpack linesearch
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer -                    1-Function value was too high
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer -                    2-Value ok, gradient positive, positive curvature
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer -                    3-Value ok, gradient negative, positive curvature
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer -                    4-Value ok, gradient negative, negative curvature
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer -                [.. B]  Backtracking
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - VALUE          The current function value
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - TIME           Total elapsed time
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - |GNORM|        The current norm of the gradient
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - {RELNORM}      The ratio of the current to initial gradient norms
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - AVEIMPROVE     The average improvement / current value
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - EVALSCORE      The last available eval score
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer -
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter ## evals ## <SCALING> [LINESEARCH] VALUE TIME |GNORM| {RELNORM} AVEIMPROVE EVALSCORE
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer -
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 373 too big: 856.4105263162287
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 428 too big: 781.9473684210762
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 2202 too big: 405.01578947333826
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 3324 too big: 1985.6789473712333
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 4023 too big: 487.97894736836463
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 4034 too big: 214.79999999989073
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 4129 too big: 1436.4263157903933
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 5350 too big: 255.96842105260384
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 5394 too big: 280.0421052631271
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 5462 too big: 313.9789473683713
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 5659 too big: 742.5263157893456
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 5874 too big: 211.41578947368316
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 6210 too big: 241.68947368412762
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 7033 too big: 343.5789473681126
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 7388 too big: 260.01578947357643
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 7611 too big: 265.13684210508643
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 7864 too big: 761.5263157893232
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 10010 too big: 435.74736842050055
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 11317 too big: 304.278947368023
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 11732 too big: 515.9473684206282
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 11740 too big: 258.1210526313418
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 12326 too big: 264.98421052622814
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 12976 too big: 200.1052631578513
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 13584 too big: 278.84736842073494
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 13761 too big: 277.4421052631578
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 13959 too big: 255.5684210526316
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 15174 too big: 505.884210526031
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 15613 too big: 288.49473684183766
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 16143 too big: 671.0473684207304
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 16182 too big: 1075.13684210638
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 16550 too big: 279.8631578946973
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 18467 too big: 253.94736842094895
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 18865 too big: 307.2473684205311
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 18867 too big: 471.947368420488
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 21194 too big: 405.01578947333826
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 21658 too big: 213.2157894736362
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 22239 too big: 788.9684210526635
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 23360 too big: 580.0578947368397
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 24765 too big: 1600.4105263178415
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 26137 too big: 221.1105263156273
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 26578 too big: 260.01578947357643
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 26579 too big: 490.7210526312962
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 27037 too big: 728.1894736840594
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 28183 too big: 527.3999999998972
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 28233 too big: 593.5684210525706
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 29347 too big: 705.4684210525129
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 31049 too big: 515.9473684206282
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 31644 too big: 221.36842105253766
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 33025 too big: 389.8842105260525
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 34260 too big: 684.0315789471638
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 34441 too big: 293.59999999992687
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 35742 too big: 329.0210526313311
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 36225 too big: 383.51052631559685
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 39265 too big: 1288.2526315795299
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 44304 too big: 522.4473684208497
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 44384 too big: 240.52105263147905
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 44389 too big: 536.110526315624
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 44406 too big: 321.5684210525051
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 45196 too big: 453.21578947333103
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 45198 too big: 221.1105263156273
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 45289 too big: 247.7473684209079
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 45625 too big: 606.9842105260822
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 45639 too big: 490.7210526312962
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 45648 too big: 603.2473684206412
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 47346 too big: 1319.3263157895356
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 49766 too big: 272.1263157893366
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 49969 too big: 724.2473684209981
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 51769 too big: 637.5210526315786
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 54272 too big: 553.2473684206229
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 54278 too big: 329.0210526313311
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 54733 too big: 383.51052631559685
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 54738 too big: 558.5157894733156
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 58309 too big: 1152.2789473694877
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 58320 too big: 649.4210526314515
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 58410 too big: 701.547368421629
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 58961 too big: 201.68947368420058
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 59015 too big: 251.6684210525756
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 59045 too big: 208.79473684207676
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 59109 too big: 573.078947368252
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 59337 too big: 788.9684210526635
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 63142 too big: 339.07894736826853
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 63151 too big: 245.22105263149183
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 63616 too big: 453.21578947333103
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 63903 too big: 330.28947368414197
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 64046 too big: 603.2473684206412
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 68135 too big: 258.1210526313418
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 68145 too big: 385.6315789471544
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 68189 too big: 457.01052631539125
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 68897 too big: 225.6105263157025
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 69987 too big: 264.47894736814635
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 71193 too big: 282.5789473681479
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 72449 too big: 300.25263157885496
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 72675 too big: 553.2473684206229
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 73128 too big: 558.5157894733156
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 73487 too big: 225.8789473682839
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 75030 too big: 282.5315789473088
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 373 too big: 216.78344522883475
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 3324 too big: 502.6354885910805
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 4129 too big: 363.60301045555104
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 16182 too big: 272.1497010631199
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 24765 too big: 405.1123812875301
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 39265 too big: 326.09576274148037
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 47346 too big: 333.9614534493857
# [main] INFO edu.stanford.nlp.maxent.iis.LambdaSolve - lambda 58309 too big: 291.67670457050895
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 1: neg. log cond. likelihood = 461714.0179063538 [4 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 1 evals 1 <D> [11M 6.456E-5] 4.617E5 2.57s |3.924E4| {6.319E-1} 0.000E0 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 2: neg. log cond. likelihood = 339753.3445846864 [5 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 2 evals 4 <D> [M 1.000E0] 3.398E5 3.58s |4.708E4| {7.582E-1} 1.795E-1 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 3: neg. log cond. likelihood = 297497.1469102535 [6 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 3 evals 5 <D> [M 1.000E0] 2.975E5 4.54s |3.141E4| {5.058E-1} 1.840E-1 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 4: neg. log cond. likelihood = 258804.56969999243 [7 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 4 evals 6 <D> [M 1.000E0] 2.588E5 5.47s |1.788E4| {2.879E-1} 1.960E-1 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 5: neg. log cond. likelihood = 235655.37116005854 [8 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 5 evals 7 <D> [M 1.000E0] 2.357E5 6.40s |1.274E4| {2.052E-1} 1.919E-1 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 6: neg. log cond. likelihood = 206283.6543074275 [9 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 6 evals 8 <D> [M 1.000E0] 2.063E5 7.33s |1.047E4| {1.686E-1} 2.064E-1 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 7: neg. log cond. likelihood = 184760.31495985834 [10 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 7 evals 9 <D> [M 1.000E0] 1.848E5 8.26s |9.365E3| {1.508E-1} 2.141E-1 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 8: neg. log cond. likelihood = 156009.82650410366 [11 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 8 evals 10 <D> [M 1.000E0] 1.560E5 9.19s |1.009E4| {1.625E-1} 2.449E-1 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 9: neg. log cond. likelihood = 137474.98166952777 [12 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 9 evals 11 <D> [M 1.000E0] 1.375E5 10.12s |7.572E3| {1.220E-1} 2.621E-1 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 10: neg. log cond. likelihood = 125511.80469860975 [13 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 10 evals 12 <D> [M 1.000E0] 1.255E5 11.04s |5.759E3| {9.275E-2} 2.679E-1 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 11: neg. log cond. likelihood = 118177.75648845777 [14 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 11 evals 13 <D> [M 1.000E0] 1.182E5 11.97s |8.319E3| {1.340E-1} 1.875E-1 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 12: neg. log cond. likelihood = 106836.96585982473 [15 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 12 evals 14 <D> [M 1.000E0] 1.068E5 12.90s |4.147E3| {6.679E-2} 1.785E-1 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 13: neg. log cond. likelihood = 101050.23590664184 [16 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 13 evals 15 <D> [M 1.000E0] 1.011E5 13.93s |3.514E3| {5.660E-2} 1.561E-1 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 14: neg. log cond. likelihood = 93405.34890139084 [17 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 14 evals 16 <D> [M 1.000E0] 9.341E4 14.88s |2.663E3| {4.289E-2} 1.523E-1 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 15: neg. log cond. likelihood = 88848.09239523123 [18 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 15 evals 17 <D> [M 1.000E0] 8.885E4 15.82s |6.562E3| {1.057E-1} 1.322E-1 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 16: neg. log cond. likelihood = 83816.20347691674 [20 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 16 evals 18 <D> [1M 4.606E-1] 8.382E4 17.46s |4.362E3| {7.025E-2} 1.204E-1 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 17: neg. log cond. likelihood = 78810.0752710504 [21 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 17 evals 20 <D> [M 1.000E0] 7.881E4 18.40s |2.020E3| {3.253E-2} 9.796E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 18: neg. log cond. likelihood = 75745.48598545481 [22 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 18 evals 21 <D> [M 1.000E0] 7.575E4 19.34s |2.021E3| {3.255E-2} 8.150E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 19: neg. log cond. likelihood = 73227.55640193234 [23 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 19 evals 22 <D> [M 1.000E0] 7.323E4 20.29s |5.968E3| {9.612E-2} 7.140E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 20: neg. log cond. likelihood = 68256.18305502509 [24 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 20 evals 23 <D> [M 1.000E0] 6.826E4 21.23s |3.228E3| {5.199E-2} 7.314E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 21: neg. log cond. likelihood = 66585.97585253028 [25 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 21 evals 24 <D> [M 1.000E0] 6.659E4 22.17s |4.130E3| {6.651E-2} 6.045E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 22: neg. log cond. likelihood = 64053.13121271361 [26 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 22 evals 25 <D> [M 1.000E0] 6.405E4 23.12s |1.383E3| {2.228E-2} 5.776E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 23: neg. log cond. likelihood = 61345.47723807563 [27 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 23 evals 26 <D> [M 1.000E0] 6.135E4 24.06s |1.667E3| {2.685E-2} 5.226E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 24: neg. log cond. likelihood = 59119.14317326943 [28 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 24 evals 27 <D> [M 1.000E0] 5.912E4 24.99s |3.576E3| {5.759E-2} 5.029E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 25: neg. log cond. likelihood = 56028.724270527455 [29 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 25 evals 28 <D> [M 1.000E0] 5.603E4 25.93s |2.485E3| {4.003E-2} 4.960E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 26: neg. log cond. likelihood = 53648.56175975514 [30 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 26 evals 29 <D> [M 1.000E0] 5.365E4 26.88s |1.699E3| {2.736E-2} 4.690E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 27: neg. log cond. likelihood = 50780.462898082355 [31 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 27 evals 30 <D> [M 1.000E0] 5.078E4 27.82s |2.243E3| {3.613E-2} 4.916E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 28: neg. log cond. likelihood = 49004.06925915816 [33 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 28 evals 31 <D> [1M 4.318E-1] 4.900E4 29.47s |2.575E3| {4.147E-2} 4.943E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 29: neg. log cond. likelihood = 47244.516458781975 [34 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 29 evals 33 <D> [M 1.000E0] 4.724E4 30.40s |1.849E3| {2.978E-2} 4.447E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 30: neg. log cond. likelihood = 45605.38285773395 [35 calls to valueAt]
# [main] INFO edu.stanford.nlp.tagger.maxent.LambdaSolveTagger - Checking model correctness; x size 177080 , ysize 19
# [main] INFO edu.stanford.nlp.tagger.maxent.LambdaSolveTagger - Constraint 10956 not satisfied emp 0.0111 exp 0.0124 diff 0.0012 lambda 4.643
# [main] INFO edu.stanford.nlp.tagger.maxent.LambdaSolveTagger - Constraint 13584 not satisfied emp 0.0173 exp 0.0159 diff 0.0014 lambda 3.2956
# [main] INFO edu.stanford.nlp.tagger.maxent.LambdaSolveTagger - Constraint 18376 not satisfied emp 0.0115 exp 0.0105 diff 0.001 lambda 0.1018
# [main] INFO edu.stanford.nlp.tagger.maxent.LambdaSolveTagger - Constraint 18865 not satisfied emp 0.0223 exp 0.0212 diff 0.0011 lambda 5.5534
# [main] INFO edu.stanford.nlp.tagger.maxent.LambdaSolveTagger - Constraint 37622 not satisfied emp 0.0115 exp 0.0105 diff 0.001 lambda 0.1018
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 30 evals 34 <D> [M 1.000E0] 4.561E4 31.34s |1.324E3| {2.133E-2} 4.600E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 31: neg. log cond. likelihood = 43090.75007097382 [36 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 31 evals 35 <D> [M 1.000E0] 4.309E4 32.56s |1.948E3| {3.137E-2} 4.865E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 32: neg. log cond. likelihood = 41925.51428300187 [38 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 32 evals 36 <D> [1M 4.000E-1] 4.193E4 34.20s |2.161E3| {3.480E-2} 4.632E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 33: neg. log cond. likelihood = 40624.02789667068 [39 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 33 evals 38 <D> [M 1.000E0] 4.062E4 35.13s |1.580E3| {2.545E-2} 4.553E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 34: neg. log cond. likelihood = 39214.034427629274 [40 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 34 evals 39 <D> [M 1.000E0] 3.921E4 36.07s |8.979E2| {1.446E-2} 4.288E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 35: neg. log cond. likelihood = 37320.77661640596 [41 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 35 evals 40 <D> [M 1.000E0] 3.732E4 37.02s |8.508E2| {1.370E-2} 4.375E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 36: neg. log cond. likelihood = 36237.94681150722 [42 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 36 evals 41 <D> [M 1.000E0] 3.624E4 37.95s |1.536E3| {2.474E-2} 4.013E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 37: neg. log cond. likelihood = 34775.88304219393 [43 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 37 evals 42 <D> [M 1.000E0] 3.478E4 38.88s |8.332E2| {1.342E-2} 4.091E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 38: neg. log cond. likelihood = 33504.51164399848 [44 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 38 evals 43 <D> [M 1.000E0] 3.350E4 39.82s |1.175E3| {1.893E-2} 4.101E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 39: neg. log cond. likelihood = 32153.596444397746 [45 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 39 evals 44 <D> [M 1.000E0] 3.215E4 40.75s |1.273E3| {2.051E-2} 4.184E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 40: neg. log cond. likelihood = 31491.765087433163 [46 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 40 evals 45 <D> [M 1.000E0] 3.149E4 41.69s |1.822E3| {2.935E-2} 3.683E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 41: neg. log cond. likelihood = 30536.523775566555 [47 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 41 evals 46 <D> [M 1.000E0] 3.054E4 42.63s |1.438E3| {2.317E-2} 3.730E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 42: neg. log cond. likelihood = 29586.251331837804 [48 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 42 evals 47 <D> [M 1.000E0] 2.959E4 43.57s |8.518E2| {1.372E-2} 3.731E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 43: neg. log cond. likelihood = 28780.63058515642 [49 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 43 evals 48 <D> [M 1.000E0] 2.878E4 44.51s |7.780E2| {1.253E-2} 3.625E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 44: neg. log cond. likelihood = 28238.277442445215 [51 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 44 evals 49 <D> [1M 4.134E-1] 2.824E4 46.14s |1.272E3| {2.049E-2} 3.216E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 45: neg. log cond. likelihood = 27411.65527723511 [52 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 45 evals 51 <D> [M 1.000E0] 2.741E4 47.07s |7.104E2| {1.144E-2} 3.220E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 46: neg. log cond. likelihood = 26685.12740308933 [53 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 46 evals 52 <D> [M 1.000E0] 2.669E4 48.00s |6.398E2| {1.030E-2} 3.032E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 47: neg. log cond. likelihood = 25855.831333952072 [54 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 47 evals 53 <D> [M 1.000E0] 2.586E4 48.93s |8.659E2| {1.395E-2} 2.958E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 48: neg. log cond. likelihood = 25059.621668736865 [55 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 48 evals 54 <D> [M 1.000E0] 2.506E4 49.87s |6.350E2| {1.023E-2} 2.831E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 49: neg. log cond. likelihood = 24356.304601337044 [56 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 49 evals 55 <D> [M 1.000E0] 2.436E4 50.80s |6.337E2| {1.021E-2} 2.930E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 50: neg. log cond. likelihood = 23645.06431255986 [57 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 50 evals 56 <D> [M 1.000E0] 2.365E4 51.73s |4.637E2| {7.468E-3} 2.915E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 51: neg. log cond. likelihood = 22665.093799689974 [58 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 51 evals 57 <D> [M 1.000E0] 2.267E4 52.67s |1.080E3| {1.740E-2} 3.054E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 52: neg. log cond. likelihood = 21778.491452030088 [59 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 52 evals 58 <D> [M 1.000E0] 2.178E4 53.61s |7.014E2| {1.130E-2} 3.215E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 53: neg. log cond. likelihood = 21744.959205278556 [60 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 53 evals 59 <D> [M 1.000E0] 2.174E4 54.55s |1.717E3| {2.766E-2} 2.986E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 54: neg. log cond. likelihood = 20998.87226596783 [61 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 54 evals 60 <D> [M 1.000E0] 2.100E4 55.48s |9.512E2| {1.532E-2} 3.054E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 55: neg. log cond. likelihood = 20494.92109728354 [62 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 55 evals 61 <D> [M 1.000E0] 2.049E4 56.41s |4.498E2| {7.245E-3} 3.020E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 56: neg. log cond. likelihood = 20115.9978558483 [63 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 56 evals 62 <D> [M 1.000E0] 2.012E4 57.34s |4.352E2| {7.009E-3} 2.853E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 57: neg. log cond. likelihood = 19773.650185470928 [65 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 57 evals 63 <D> [1M 1.772E-1] 1.977E4 58.98s |9.067E2| {1.460E-2} 2.673E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 58: neg. log cond. likelihood = 19228.155488389613 [66 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 58 evals 65 <D> [M 1.000E0] 1.923E4 59.92s |4.037E2| {6.502E-3} 2.667E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 59: neg. log cond. likelihood = 18951.590039699426 [67 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 59 evals 66 <D> [M 1.000E0] 1.895E4 60.85s |3.665E2| {5.902E-3} 2.477E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 60: neg. log cond. likelihood = 18491.38586935637 [68 calls to valueAt]
# [main] INFO edu.stanford.nlp.tagger.maxent.LambdaSolveTagger - Checking model correctness; x size 177080 , ysize 19
# [main] INFO edu.stanford.nlp.tagger.maxent.LambdaSolveTagger - Constraint 7864 not satisfied emp 0.0363 exp 0.0353 diff 0.0011 lambda 7.4126
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 60 evals 67 <D> [M 1.000E0] 1.849E4 61.79s |9.836E2| {1.584E-2} 2.257E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 61: neg. log cond. likelihood = 18333.01513368118 [69 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 61 evals 68 <D> [M 1.000E0] 1.833E4 62.97s |1.093E3| {1.761E-2} 1.879E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 62: neg. log cond. likelihood = 17777.237757146875 [70 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 62 evals 69 <D> [M 1.000E0] 1.778E4 63.91s |3.414E2| {5.498E-3} 2.232E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 63: neg. log cond. likelihood = 17440.581182925827 [71 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 63 evals 70 <D> [M 1.000E0] 1.744E4 64.84s |2.553E2| {4.112E-3} 2.040E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 64: neg. log cond. likelihood = 16944.712533021684 [72 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 64 evals 71 <D> [M 1.000E0] 1.694E4 65.77s |8.048E2| {1.296E-2} 2.095E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 65: neg. log cond. likelihood = 16557.535022435244 [73 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 65 evals 72 <D> [M 1.000E0] 1.656E4 66.71s |8.911E2| {1.435E-2} 2.149E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 66: neg. log cond. likelihood = 16115.63997299838 [74 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 66 evals 73 <D> [M 1.000E0] 1.612E4 67.64s |6.823E2| {1.099E-2} 2.270E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 67: neg. log cond. likelihood = 16017.880512393802 [75 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 67 evals 74 <D> [M 1.000E0] 1.602E4 68.58s |1.087E3| {1.750E-2} 2.004E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 68: neg. log cond. likelihood = 15592.513286419258 [76 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 68 evals 75 <D> [M 1.000E0] 1.559E4 69.52s |5.045E2| {8.126E-3} 2.154E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 69: neg. log cond. likelihood = 15497.719926588643 [77 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 69 evals 76 <D> [M 1.000E0] 1.550E4 70.46s |9.584E2| {1.543E-2} 1.932E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 70: neg. log cond. likelihood = 15172.093229726173 [78 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 70 evals 77 <D> [M 1.000E0] 1.517E4 71.45s |3.635E2| {5.854E-3} 2.083E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 71: neg. log cond. likelihood = 14837.900117160612 [79 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 71 evals 78 <D> [M 1.000E0] 1.484E4 72.44s |3.666E2| {5.904E-3} 1.981E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 72: neg. log cond. likelihood = 14398.940103977033 [80 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 72 evals 79 <D> [M 1.000E0] 1.440E4 73.38s |4.916E2| {7.918E-3} 2.112E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 73: neg. log cond. likelihood = 14147.579612971365 [82 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 73 evals 80 <D> [1M 4.479E-1] 1.415E4 75.03s |6.818E2| {1.098E-2} 1.977E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 74: neg. log cond. likelihood = 13837.815806562152 [83 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 74 evals 82 <D> [M 1.000E0] 1.384E4 75.97s |3.785E2| {6.095E-3} 1.965E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 75: neg. log cond. likelihood = 13720.680595732196 [84 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 75 evals 83 <D> [M 1.000E0] 1.372E4 76.91s |7.209E2| {1.161E-2} 1.746E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 76: neg. log cond. likelihood = 13316.03584080402 [85 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 76 evals 84 <D> [M 1.000E0] 1.332E4 77.84s |3.099E2| {4.992E-3} 2.029E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 77: neg. log cond. likelihood = 13112.482394674962 [86 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 77 evals 85 <D> [M 1.000E0] 1.311E4 78.78s |4.777E2| {7.693E-3} 1.891E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 78: neg. log cond. likelihood = 12797.301701912324 [87 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 78 evals 86 <D> [M 1.000E0] 1.280E4 79.71s |4.255E2| {6.853E-3} 2.110E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 79: neg. log cond. likelihood = 12567.199588450409 [89 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 79 evals 87 <D> [1M 4.029E-1] 1.257E4 81.34s |5.073E2| {8.170E-3} 2.073E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 80: neg. log cond. likelihood = 12353.327543418922 [90 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 80 evals 89 <D> [M 1.000E0] 1.235E4 82.27s |4.112E2| {6.623E-3} 2.011E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 81: neg. log cond. likelihood = 12183.322182492177 [91 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 81 evals 90 <D> [M 1.000E0] 1.218E4 83.20s |3.038E2| {4.893E-3} 1.819E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 82: neg. log cond. likelihood = 11983.799801612946 [92 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 82 evals 91 <D> [M 1.000E0] 1.198E4 84.13s |2.754E2| {4.435E-3} 1.806E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 83: neg. log cond. likelihood = 11632.433927353703 [93 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 83 evals 92 <D> [M 1.000E0] 1.163E4 85.06s |3.834E2| {6.174E-3} 1.896E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 84: neg. log cond. likelihood = 11479.00474929025 [94 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 84 evals 93 <D> [M 1.000E0] 1.148E4 86.00s |4.895E2| {7.883E-3} 1.953E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 85: neg. log cond. likelihood = 11265.445156122962 [95 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 85 evals 94 <D> [M 1.000E0] 1.127E4 86.94s |2.891E2| {4.656E-3} 1.820E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 86: neg. log cond. likelihood = 11159.52586405051 [96 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 86 evals 95 <D> [M 1.000E0] 1.116E4 87.87s |5.715E2| {9.204E-3} 1.750E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 87: neg. log cond. likelihood = 10886.27275952468 [97 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 87 evals 96 <D> [M 1.000E0] 1.089E4 88.80s |2.811E2| {4.527E-3} 1.755E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 88: neg. log cond. likelihood = 10712.721665894138 [98 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 88 evals 97 <D> [M 1.000E0] 1.071E4 89.72s |1.820E2| {2.932E-3} 1.731E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 89: neg. log cond. likelihood = 10487.954167656502 [99 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 89 evals 98 <D> [M 1.000E0] 1.049E4 90.66s |3.386E2| {5.453E-3} 1.779E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 90: neg. log cond. likelihood = 10301.630628443987 [100 calls to valueAt]
# [main] INFO edu.stanford.nlp.tagger.maxent.LambdaSolveTagger - Checking model correctness; x size 177080 , ysize 19
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 90 evals 99 <D> [M 1.000E0] 1.030E4 91.59s |3.048E2| {4.909E-3} 1.827E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 91: neg. log cond. likelihood = 10116.54271367653 [101 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 91 evals 100 <D> [M 1.000E0] 1.012E4 92.77s |4.016E2| {6.467E-3} 1.846E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 92: neg. log cond. likelihood = 9991.169232475959 [103 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 92 evals 101 <D> [1M 3.409E-1] 9.991E3 94.38s |3.476E2| {5.598E-3} 1.643E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 93: neg. log cond. likelihood = 9859.283663363432 [104 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 93 evals 103 <D> [M 1.000E0] 9.859E3 95.31s |1.597E2| {2.572E-3} 1.643E-2 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 94: neg. log cond. likelihood = 9724.960512875075 [105 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 94 evals 104 <D> [M 1.000E0] 9.725E3 96.24s |1.947E2| {3.135E-3} 1.584E-2 -
# ...
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 269: neg. log cond. likelihood = 5561.5926295628715 [288 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 269 evals 287 <D> [M 1.000E0] 5.562E3 267.04s |5.084E1| {8.188E-4} 2.744E-4 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 270: neg. log cond. likelihood = 5559.753870368304 [289 calls to valueAt]
# [main] INFO edu.stanford.nlp.tagger.maxent.LambdaSolveTagger - Checking model correctness; x size 177080 , ysize 19
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 270 evals 288 <D> [M 1.000E0] 5.560E3 267.95s |2.151E1| {3.464E-4} 2.739E-4 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 271: neg. log cond. likelihood = 5557.823504256999 [290 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 271 evals 289 <D> [M 1.000E0] 5.558E3 269.21s |1.221E1| {1.967E-4} 2.891E-4 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 272: neg. log cond. likelihood = 5556.195873767693 [291 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 272 evals 290 <D> [M 1.000E0] 5.556E3 270.13s |1.312E1| {2.113E-4} 2.747E-4 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 273: neg. log cond. likelihood = 5553.906590173731 [292 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 273 evals 291 <D> [M 1.000E0] 5.554E3 271.09s |2.219E1| {3.574E-4} 2.887E-4 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 274: neg. log cond. likelihood = 5552.3935163102105 [293 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 274 evals 292 <D> [M 1.000E0] 5.552E3 272.05s |2.153E1| {3.467E-4} 2.793E-4 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 275: neg. log cond. likelihood = 5550.932083784154 [294 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 275 evals 293 <D> [M 1.000E0] 5.551E3 272.98s |2.036E1| {3.278E-4} 2.879E-4 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 276: neg. log cond. likelihood = 5549.218069661782 [295 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 276 evals 294 <D> [M 1.000E0] 5.549E3 273.91s |1.618E1| {2.606E-4} 2.768E-4 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 277: neg. log cond. likelihood = 5547.689920050494 [296 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 277 evals 295 <D> [M 1.000E0] 5.548E3 274.84s |9.158E0| {1.475E-4} 2.773E-4 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 278: neg. log cond. likelihood = 5545.8661569982005 [297 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 278 evals 296 <D> [M 1.000E0] 5.546E3 275.77s |2.834E1| {4.564E-4} 2.836E-4 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 279: neg. log cond. likelihood = 5543.891790037346 [298 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 279 evals 297 <D> [M 1.000E0] 5.544E3 276.72s |1.431E1| {2.305E-4} 2.861E-4 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 280: neg. log cond. likelihood = 5542.744534010457 [299 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 280 evals 298 <D> [M 1.000E0] 5.543E3 277.67s |1.861E1| {2.997E-4} 2.720E-4 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 281: neg. log cond. likelihood = 5541.093162962464 [300 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 281 evals 299 <D> [M 1.000E0] 5.541E3 278.60s |1.456E1| {2.345E-4} 2.726E-4 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 282: neg. log cond. likelihood = 5540.380072410816 [301 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 282 evals 300 <D> [M 1.000E0] 5.540E3 279.51s |3.369E1| {5.426E-4} 2.441E-4 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 283: neg. log cond. likelihood = 5538.146137044841 [302 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 283 evals 301 <D> [M 1.000E0] 5.538E3 280.43s |1.426E1| {2.297E-4} 2.573E-4 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 284: neg. log cond. likelihood = 5536.8585648034295 [303 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 284 evals 302 <D> [M 1.000E0] 5.537E3 281.35s |1.282E1| {2.065E-4} 2.542E-4 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 285: neg. log cond. likelihood = 5535.047568189018 [304 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 285 evals 303 <D> [M 1.000E0] 5.535E3 282.28s |1.052E1| {1.694E-4} 2.560E-4 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 286: neg. log cond. likelihood = 5533.613694344731 [306 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 286 evals 304 <D> [2M 5.104E-1] 5.534E3 283.87s |2.041E1| {3.288E-4} 2.544E-4 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 287: neg. log cond. likelihood = 5532.254977861807 [307 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 287 evals 306 <D> [M 1.000E0] 5.532E3 284.81s |1.753E1| {2.824E-4} 2.460E-4 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 288: neg. log cond. likelihood = 5531.1213200326465 [308 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 288 evals 307 <D> [M 1.000E0] 5.531E3 285.75s |1.024E1| {1.648E-4} 2.309E-4 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 289: neg. log cond. likelihood = 5529.749607347471 [309 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 289 evals 308 <D> [M 1.000E0] 5.530E3 286.69s |9.564E0| {1.540E-4} 2.350E-4 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 290: neg. log cond. likelihood = 5528.119429776147 [310 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 290 evals 309 <D> [M 1.000E0] 5.528E3 287.61s |1.718E1| {2.767E-4} 2.347E-4 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 291: neg. log cond. likelihood = 5526.9112358422235 [311 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 291 evals 310 <D> [M 1.000E0] 5.527E3 288.55s |1.100E1| {1.772E-4} 2.437E-4 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 292: neg. log cond. likelihood = 5525.132000454226 [312 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 292 evals 311 <D> [M 1.000E0] 5.525E3 289.47s |1.485E1| {2.391E-4} 2.355E-4 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 293: neg. log cond. likelihood = 5523.643168920936 [313 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 293 evals 312 <D> [M 1.000E0] 5.524E3 290.38s |1.606E1| {2.587E-4} 2.393E-4 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 294: neg. log cond. likelihood = 5521.904221765505 [314 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 294 evals 313 <D> [M 1.000E0] 5.522E3 291.30s |9.832E0| {1.584E-4} 2.380E-4 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 295: neg. log cond. likelihood = 5521.170501444591 [315 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 295 evals 314 <D> [M 1.000E0] 5.521E3 292.21s |3.242E1| {5.221E-4} 2.254E-4 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 296: neg. log cond. likelihood = 5519.628432480397 [316 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 296 evals 315 <D> [M 1.000E0] 5.520E3 293.13s |1.785E1| {2.875E-4} 2.288E-4 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 297: neg. log cond. likelihood = 5519.003094001665 [317 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 297 evals 316 <D> [M 1.000E0] 5.519E3 294.04s |2.393E1| {3.853E-4} 2.196E-4 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 298: neg. log cond. likelihood = 5517.748867510815 [318 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 298 evals 317 <D> [M 1.000E0] 5.518E3 294.96s |6.789E0| {1.093E-4} 2.175E-4 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 299: neg. log cond. likelihood = 5516.6950198937075 [319 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 299 evals 318 <D> [M 1.000E0] 5.517E3 295.88s |8.706E0| {1.402E-4} 2.071E-4 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 300: neg. log cond. likelihood = 5515.6571927188 [321 calls to valueAt]
# [main] INFO edu.stanford.nlp.tagger.maxent.LambdaSolveTagger - Checking model correctness; x size 177080 , ysize 19
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 300 evals 319 <D> [2M 5.219E-1] 5.516E3 297.51s |2.485E1| {4.002E-4} 2.040E-4 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 301: neg. log cond. likelihood = 5514.229571482932 [322 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 301 evals 321 <D> [M 1.000E0] 5.514E3 298.71s |1.519E1| {2.447E-4} 1.977E-4 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 302: neg. log cond. likelihood = 5513.148663529747 [323 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 302 evals 322 <D> [M 1.000E0] 5.513E3 299.62s |1.539E1| {2.479E-4} 1.904E-4 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 303: neg. log cond. likelihood = 5511.77511997044 [324 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 303 evals 323 <D> [M 1.000E0] 5.512E3 300.53s |1.183E1| {1.905E-4} 1.838E-4 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 304: neg. log cond. likelihood = 5510.669477193124 [325 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 304 evals 324 <D> [M 1.000E0] 5.511E3 301.44s |1.139E1| {1.835E-4} 1.906E-4 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 305: neg. log cond. likelihood = 5509.294600130982 [326 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 305 evals 325 <D> [M 1.000E0] 5.509E3 302.35s |1.588E1| {2.558E-4} 1.876E-4 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 306: neg. log cond. likelihood = 5508.804788552146 [327 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 306 evals 326 <D> [M 1.000E0] 5.509E3 303.27s |1.820E1| {2.931E-4} 1.851E-4 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 307: neg. log cond. likelihood = 5507.320563112474 [328 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 307 evals 327 <D> [M 1.000E0] 5.507E3 304.17s |7.026E0| {1.132E-4} 1.894E-4 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 308: neg. log cond. likelihood = 5506.671423389937 [329 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 308 evals 328 <D> [M 1.000E0] 5.507E3 305.08s |1.856E1| {2.989E-4} 1.820E-4 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 309: neg. log cond. likelihood = 5505.585547808859 [330 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 309 evals 329 <D> [M 1.000E0] 5.506E3 305.99s |1.675E1| {2.698E-4} 1.829E-4 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 310: neg. log cond. likelihood = 5504.5370790509105 [331 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 310 evals 330 <D> [M 1.000E0] 5.505E3 306.91s |1.302E1| {2.097E-4} 1.761E-4 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 311: neg. log cond. likelihood = 5503.4414819240465 [332 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 311 evals 331 <D> [M 1.000E0] 5.503E3 307.82s |4.966E0| {7.999E-5} 1.764E-4 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 312: neg. log cond. likelihood = 5502.577192303389 [333 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 312 evals 332 <D> [M 1.000E0] 5.503E3 308.74s |1.753E1| {2.824E-4} 1.672E-4 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 313: neg. log cond. likelihood = 5501.4837441092695 [334 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 313 evals 333 <D> [M 1.000E0] 5.501E3 309.65s |2.044E1| {3.292E-4} 1.670E-4 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 314: neg. log cond. likelihood = 5500.721732518551 [335 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 314 evals 334 <D> [M 1.000E0] 5.501E3 310.56s |1.106E1| {1.781E-4} 1.558E-4 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 315: neg. log cond. likelihood = 5499.732593544543 [336 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 315 evals 335 <D> [M 1.000E0] 5.500E3 311.47s |5.359E0| {8.630E-5} 1.650E-4 -
# [main] INFO CoreNLP - class edu.stanford.nlp.maxent.CGRunner
# [main] INFO edu.stanford.nlp.maxent.CGRunner - Iter. 316: neg. log cond. likelihood = 5498.616460804794 [337 calls to valueAt]
# [main] INFO edu.stanford.nlp.optimization.QNMinimizer - Iter 316 evals 336 <D> [M 1.000E0] 5.499E3 312.38s |1.586E1| {2.555E-4} 1.583E-4 -

# %% [markdown]
# ## Parser
# Com o tagger treinado, podemos treinar o parser. Note que as ferramentas do CoreNLP não seguem sempre o mesmo padrão de configuração: enquanto o POS tagger usa um arquivo com os parâmetros, para o parser de dependências é tudo via linha de comando

# %%
# !java -cp "javanlp-core.jar:stanford-corenlp-full-2018-10-05/*" -Xmx4g  edu.stanford.nlp.parser.nndep.DependencyParser -trainFile pt-ud-train_sem_metadados.conllu -embeddingSize 600 -model portuguese-ud-dep.sp

# %%
# !java -cp "javanlp-core.jar:stanford-corenlp-full-2018-10-05/*" edu.stanford.nlp.parser.nndep.DependencyParser -model portugue-dep-parser -testFile /path/to/stanford-corenlp-full-2018-10-05/bosque2.5/pt-ud-test.conllu

# %% [markdown]
# Para rodar o parser com um texto qualquer, é só executar o comando:

# %%
# !java -cp "javanlp-core.jar:/path/to/stanford-corenlp-full-2018-10-05/*" edu.stanford.nlp.parser.nndep.DependencyParser -model portuguese-dep-parser -tagger.model portuguese-ud.tagger -textFile arquivo.txt
